# %% [markdown]
# Exercise 1: Greeting Function.
#
# Complete the "Greeting Function" exercise.
#
# Instructions:
#
# Write Python code to solve the "Greeting Function" challenge.
#
# Follow the instructions and make sure your output matches the expected result.

# %%
def greeting():
  print("hello world!")

greeting()

# %% [markdown]
# Exercise 2: Rectangle Perimeter.
#
# Complete the "Rectangle Perimeter" exercise.
#
# Instructions:
#
# Write Python code to solve the "Rectangle Perimeter" challenge.
#
# Follow the instructions and make sure your output matches the expected result.

# %%
def cal_perimeter(length, width):
    return 2 * (length + width)

print(cal_perimeter(10, 20))
# Out:
# 60
