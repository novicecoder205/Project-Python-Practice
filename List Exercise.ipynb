# %% [markdown]
# Exercise: List.
#
# Attempt to the 30-Days-Python.

# %%
# 1. Declare an empty list:
list1 = list()

# %%
# 2. Declare a list with more than 5 items:
listA = ['apple', 'banana', 'grape', 'tomato', 'strawberry']
print(listA)
# Out:
# ['apple', 'banana', 'grape', 'tomato', 'strawberry']

# %%
# 3. Find the length of your list:
listA = ['apple', 'banana', 'grape', 'tomato', 'strawberry']
print("Number of items in your list: ", len(listA))
# Out:
# Number of items in your list:  5

# %%
# 4. Get the first items, the middle item and the last item of the list.
ListB = ['a1', 'a2', 'a3', 'a4', 'a5']
first_item = ListB[0]
print(first_item)
second_item = ListB[1]
print(second_item)
last_item = len(ListB) - 1
last_item_on_list = ListB[last_item]
print(last_item_on_list)
# Out:
# a1
# a2
# a5

# %%
# 5. Declare a list called mixed_data_types, put your(name, age, height, marital status, address)
list_detail = ['Robert', 21, 1.6, "F", "21 Avernue"]
name = list_detail[0]
print(name)
age = list_detail[1]
print(age)
height = list_detail[2]
print(height)
marital_status = list_detail[3]
print(marital_status)
address = list_detail[4]
print(address)
# Out:
# Robert
# 21
# 1.6
# F
# 21 Avernue

# %%
# 6-7. Declare a list variable named it_companies and assign initial values Facebook, Google, Microsoft, Apple, IBM, Oracle and Amazon.
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 8. Print the number of companies in the list:
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
length_companies = len(it_companies)
print(length_companies)
# Out:
# 7

# %%
# 9. Print the first, middle and last company:
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
first_item = it_companies[0]
middle_item = it_companies[len(it_companies) // 2]
last_item = it_companies[-1]

print("First:", first_item)
print("Middle:", middle_item)
print("Last:", last_item)
# Out:
# First: Facebook
# Middle: Apple
# Last: Amazon

# %%
# 10. Print the list after modifying one of the companies:
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies[1] = "Chicken"
print(it_companies)
# Out:
# ['Facebook', 'Chicken', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 11. Add an IT company to it_companies:
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies.insert(3, 'Demon')
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Demon', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 12. Insert an IT company in the middle of the companies list
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies.append('Target')
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Target']

# %%
# 13. Change one of the it_companies names to uppercase (IBM excluded!)
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies[1] = it_companies[1].upper()
print(it_companies)
# Out:
# ['Facebook', 'GOOGLE', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# 14. Join the it_companies with a string '#;  '
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
result = '#;'.join(it_companies)
print(result)
# Out:
# Facebook#;Google#;Microsoft#;Apple#;IBM#;Oracle#;Amazon

# %%
# 15. Check if a certain company exists in the it_companies list.
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
does_exist = 'Facebook' , 'Google' in it_companies
print(does_exist)
does_not_exist = 'Lime', 'Orange' in it_companies
print(does_not_exist)
# Out:
# ('Facebook', True)
# ('Lime', False)

# %%
# 16. Sort the list using sort() method
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies.sort()
print(it_companies)
it_companies.sort(reverse=True)
print(it_companies)

ages = [22, 19, 24, 25, 26, 24, 25, 24]
ages.sort()
print(ages) #  [19, 22, 24, 24, 24, 25, 25, 26]

ages.sort(reverse=True)
print(ages) #  [26, 25, 25, 24, 24, 24, 22, 19]
# Out:
# ['Amazon', 'Apple', 'Facebook', 'Google', 'IBM', 'Microsoft', 'Oracle']
# ['Oracle', 'Microsoft', 'IBM', 'Google', 'Facebook', 'Apple', 'Amazon']
# [19, 22, 24, 24, 24, 25, 25, 26]
# [26, 25, 25, 24, 24, 24, 22, 19]

# %%
# 17. Reverse the list in descending order using reverse() method
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
it_companies.sort(reverse=True)
print(it_companies)
# Out:
# ['Oracle', 'Microsoft', 'IBM', 'Google', 'Facebook', 'Apple', 'Amazon']

# %%
# 18. Slice out the first 3 companies from the list
it_companies = ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
all_companies = it_companies[0:7]

# %%
# 19. Slice out the last 3 companies from the list

# %%
# 20. Slice out the middle IT company or companies from the list

# %%
# 21. Remove the first IT company from the list

# %%
# 22. Remove the middle IT company or companies from the list

# %%
# 23. Remove the last IT company from the list

# %%
# 24. Remove all IT companies from the list

# %%
# 25. Destroy the IT companies list

# %%
# 26. Join the following lists:
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

# %%
# 27. After joining the lists in question 26. Copy the joined list and assign it to a variable full_stack, then insert Python and SQL after Redux.
