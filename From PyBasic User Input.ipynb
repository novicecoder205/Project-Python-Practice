# %% [markdown]
# #### PyBasic: User Input & Type Casting.

# %%
# Practice Arena:

# %% [markdown]
# Greeting by Name
# Complete the "Greeting by Name" exercise.
#
# Instructions
# Write Python code to solve the "Greeting by Name" challenge. Follow the instructions and make sure your output matches the expected result.

# %%
name = input("What is your name? ")
print(f"Hello, {name}!")
# Out:
# What is your name?  Robot bo
# Hello, Robot bo!
